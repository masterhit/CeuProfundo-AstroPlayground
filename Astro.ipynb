# %%
import matplotlib.pyplot as plt
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)
image_file = input('Image file: ')
from astropy.io import fits

# %%
fits.info(image_file)
# Out:
# Filename: D:\FITS\Globular_NGC18\ick002010_drc.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    1024   ()
#   1  SCI           1 ImageHDU        96   (4132, 4419)   float32
#   2  WHT           1 ImageHDU        45   (4132, 4419)   float32
#   3  CTX           1 ImageHDU        40   (4132, 4419)   int32
#   4  HDRTAB        1 BinTableHDU    559   14R x 275C   [9A, 3A, K, D, D, D, D, D, D, D, D, D, D, D, D, K, 11A, 9A, 7A, 18A, 4A, D, D, D, D, 3A, D, D, D, D, D, D, D, D, D, D, D, D, K, K, 8A, 23A, D, D, D, D, K, K, 8A, 23A, 9A, 18A, 4A, K, D, D, D, K, K, K, K, 23A, D, D, D, D, K, K, 4A, 3A, 4A, L, D, D, D, 23A, 1A, K, D, D, D, 4A, 1A, 12A, 12A, 8A, 23A, D, D, 10A, 10A, D, D, D, 4A, 3A, 3A, 4A, 8A, 7A, D, K, D, 6A, 9A, 8A, D, D, 4A, 18A, 3A, K, 5A, 3A, D, 10A, 8A, 8A, 23A, D, D, D, 3A, 1A, D, 23A, D, D, D, 3A, L, 1A, 4A, D, 3A, 6A, D, D, D, D, D, 23A, D, D, D, D, D, 1A, K, K, K, K, D, 3A, K, D, 5A, 7A, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, 12A, D, 24A, 23A, D, 1A, 1A, D, K, D, D, 1A, 1A, D, D, D, D, D, D, D, D, D, D, D, 4A, D, K, 23A, D, 8A, D, D, 31A, D, D, L, D, D, 5A, 7A, 1A, 4A, D, 1A, K, 1A, 1A, 1A, 1A, D, D, D, D, D, D, 4A, D, D, D, D, D, D, D, D, D, D, D, D, 4A, K, 4A, 3A, 1A, L, K, K, 1A, D, D, D, D, K, L, 6A, L, D, D, D, 1A, 8A, D, 3A, 8A, D, D, K, D, 29A, D, D]

# %%
image_data = fits.getdata(image_file, ext=0)

# %%
print(image_data.shape)
# Out:
# (4419, 4132)

# %%
plt.figure()
plt.imshow(image_data, cmap='gray')
plt.colorbar()
